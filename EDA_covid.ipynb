# %%
import pandas as pd
#import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import seaborn as sns

# %%
#data
dataset_df = pd.read_csv("data_covid19.csv")

# %%
dataset_df
# Out:
#     Usia  Demam  Batuk Kering  Sakit Tenggorokan  Sakit Kepala  Lemas  \
# 0     25      1             1                  1             1      1
# 1     25      0             0                  0             0      0
# 2     23      0             1                  1             1      1
# 3     34      1             0                  1             0      1
# 4     45      0             1                  0             1      0
# ..   ...    ...           ...                ...           ...    ...
# 94    32      0             1                  0             1      0
# 95    33      1             1                  1             0      1
# 96    34      0             0                  1             0      1
# 97    35      0             1                  0             0      0
# 98    36      0             0                  1             1      1
#
#     Sesak Nafas  Diagnosa
# 0             1         1
# 1             0         0
# 2             0         1
# ...

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Usia               99 non-null     int64
#  1   Demam              99 non-null     int64
#  2   Batuk Kering       99 non-null     int64
#  3   Sakit Tenggorokan  99 non-null     int64
#  4   Sakit Kepala       99 non-null     int64
#  5   Lemas              99 non-null     int64
#  6   Sesak Nafas        99 non-null     int64
#  7   Diagnosa           99 non-null     int64
# dtypes: int64(8)
# memory usage: 6.3 KB

# %%
dataset_df['Usia'].plot(kind='box')

# %% [markdown]
# kotak panjang itu disebut whisker, boxplot biasanya dipake untuk melihat distribusi data apakah ada outlier ato tidak. warna merah tersebut dpt dikatakan bahwa pada data tsb rata usia dr hasil survey adalah ...
# apabila ada titik kecil dilur kotak maka titik kecil tsb menunjukan adanya outlier/pencilan data. outlier tidak perlu dihapus krn hal tsb dapat mengetahui adanya anomali pada data.

# %%
dataset_df['Usia'].plot(kind='hist')

# %%
sns.distplot(dataset_df["Usia"],color="g")

# %% [markdown]
# visualisasi ini jg untuk melihat distribusi frekuensi data pada kolom usia. Fungsi ini akan memvisualisasikan histogram yang sesuai dengan estimasi kepadatan kernel/Kernel Density Estimation (KDE) dari data

# %%
df_good = dataset_df[dataset_df["Diagnosa"] == 1]
df_bad = dataset_df[dataset_df["Diagnosa"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Demam"] == 1]
df_bad = dataset_df[dataset_df["Demam"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Batuk Kering"] == 1]
df_bad = dataset_df[dataset_df["Batuk Kering"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Sakit Tenggorokan"] == 1]
df_bad = dataset_df[dataset_df["Sakit Tenggorokan"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Sakit Kepala"] == 1]
df_bad = dataset_df[dataset_df["Sakit Kepala"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Lemas"] == 1]
df_bad = dataset_df[dataset_df["Lemas"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
df_good = dataset_df[dataset_df["Sesak Nafas"] == 1]
df_bad = dataset_df[dataset_df["Sesak Nafas"] == 0]

fig, ax = plt.subplots(nrows=2, figsize=(12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(df_good["Usia"], ax=ax[0], 
             color="g")
g1 = sns.distplot(df_bad["Usia"], ax=ax[1], 
             color='r')

# %%
pd.crosstab(dataset_df["Usia"], dataset_df['Diagnosa'],margins=True)
# Out:
# Diagnosa   0   1  All
# Usia
# 18         0   1    1
# 19         1   1    2
# 20         1   1    2
# 21         1   1    2
# 22         0   2    2
# 23         3   3    6
# 24         1   2    3
# 25         3   2    5
# 26         1   2    3
# 27         2   1    3
# 28         2   1    3
# 29         1   2    3
# 30         1   2    3
# 31         2   1    3
# 32         2   1    3
# 33         0   3    3
# 34         2   2    4
# 35         2   1    3
# 36         1   2    3
# 37         0   2    2
# 38         2   0    2
# 39         1   1    2
# 40         1   1    2
# 41         1   1    2
# 42         1   1    2
# 43         2   1    3
# 44         1   1    2
# 45         1   2    3
# 46         1   0    1
# 47         0   1    1
# 48         0   1    1
# 49         1   0    1
# 50         0   1    1
# 51         1   0    1
# 52         0   1    1
# 53         1   0    1
# 54         0   1    1
# 55         1   0    1
# 56         2   3    5
# 57         1   0    1
# ...

# %%
check = pd.crosstab(dataset_df["Usia"], dataset_df['Diagnosa'],margins=True)

# %%
check.div(check.sum()).T.plot(kind='bar',stacked=True)

# %%
a=[2,3,4,5,9,10]
for i in range(0,len(a)):
    plt.figure(figsize=(15,5))
    sns.boxplot(y='Usia', x=dataset_df.columns[a[i]], 
                 data=dataset_df, 
                 width=0.5,
                 palette="colorblind")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-0254848b6d24> in <module>
#       2 for i in range(0,len(a)):
#       3     plt.figure(figsize=(15,5))
# ----> 4     sns.boxplot(y='Usia', x=dataset_df.columns[a[i]],
#       5                  data=dataset_df,
#       6                  width=0.5,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 9 is out of bounds for axis 0 with size 8

# %%
a=[2,3,4,5,9,10]
for i in range(0,len(a)):
    plt.figure(figsize=(15,5))
    sns.violinplot(y='Usia', x=dataset_df.columns[a[i]],
                hue='Diagnosa', 
                 data=dataset_df, 
                 width=0.5,
                 palette="colorblind",split=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-d9b4a43f86fe> in <module>
#       2 for i in range(0,len(a)):
#       3     plt.figure(figsize=(15,5))
# ----> 4     sns.violinplot(y='Usia', x=dataset_df.columns[a[i]],
#       5                 hue='Diagnosa',
#       6                  data=dataset_df,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 9 is out of bounds for axis 0 with size 8

# %%
sns.lmplot('Usia','Batuk Kering',data=dataset_df,col='Diagnosa',scatter_kws=dict(color='c'))

# %% [markdown]
# visualisasi untuk 2 variabel/peubah yg berbeda

# %%
dataset_df.describe()
# Out:
#             Usia      Demam  Batuk Kering  Sakit Tenggorokan  Sakit Kepala  \
# count  99.000000  99.000000     99.000000          99.000000     99.000000
# mean   36.414141   0.333333      0.535354           0.666667      0.464646
# std    12.119313   0.473804      0.501287           0.473804      0.501287
# min    18.000000   0.000000      0.000000           0.000000      0.000000
# 25%    26.000000   0.000000      0.000000           0.000000      0.000000
# 50%    34.000000   0.000000      1.000000           1.000000      0.000000
# 75%    44.500000   1.000000      1.000000           1.000000      1.000000
# max    63.000000   1.000000      1.000000           1.000000      1.000000
#
#            Lemas  Sesak Nafas   Diagnosa
# count  99.000000    99.000000  99.000000
# mean    0.606061     0.434343   0.535354
# std     0.491108     0.498193   0.501287
# min     0.000000     0.000000   0.000000
# 25%     0.000000     0.000000   0.000000
# 50%     1.000000     0.000000   1.000000
# ...
